# %% [markdown]
# <a href="https://colab.research.google.com/github/Ansebi/Hello_LSTM/blob/main/20221108_hello_LSTM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Imports

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

# %% [markdown]
# # Generate $sin(x)$-based time series

# %%
n_years = 3
alpha = 1/6
beta = 0.9
amplitude = 1
elevation_power = 2.2
amplitude_change_power = 2
period_starts = pd.Timestamp('2022-01-01')

duration_days = 365*n_years
period_ends = period_starts + pd.Timedelta(days=duration_days)

x = np.linspace(1, duration_days, duration_days*24)
y = x**elevation_power
y += amplitude*x**amplitude_change_power*np.sin(x**beta*alpha)
x_date = pd.date_range(period_starts, period_ends, freq='H')[:-1]

plt.figure(figsize=(24,3))
plt.scatter(x=x_date, y=y)
plt.show()

# %% [markdown]
# # Jason Brownlee's examples

# %%
# # split a univariate sequence into samples
# def split_sequence(sequence, n_steps):
# 	X, y = list(), list()
# 	for i in range(len(sequence)):
# 		# find the end of this pattern
# 		end_ix = i + n_steps
# 		# check if we are beyond the sequence
# 		if end_ix > len(sequence)-1:
# 			break
# 		# gather input and output parts of the pattern
# 		seq_x, seq_y = sequence[i:end_ix], sequence[end_ix]
# 		X.append(seq_x)
# 		y.append(seq_y)
# 	return array(X), array(y)
 
# # define input sequence
# raw_seq = [10, 20, 30, 40, 50, 60, 70, 80, 90]
# # choose a number of time steps
# n_steps = 3
# # split into samples
# X, y = split_sequence(raw_seq, n_steps)
# # reshape from [samples, timesteps] into [samples, timesteps, features]
# n_features = 1
# X = X.reshape((X.shape[0], X.shape[1], n_features))
# # define model
# model = Sequential()
# model.add(LSTM(50, activation='relu', input_shape=(n_steps, n_features)))
# model.add(Dense(1))
# model.compile(optimizer='adam', loss='mse')
# # fit model
# model.fit(X, y, epochs=200, verbose=0)
# # demonstrate prediction
# x_input = array([70, 80, 90])
# x_input = x_input.reshape((1, n_steps, n_features))
# yhat = model.predict(x_input, verbose=0)
# print(yhat)

# %%
# # univariate stacked lstm example
# from numpy import array
# from keras.models import Sequential
# from keras.layers import LSTM
# from keras.layers import Dense
 
# # split a univariate sequence
# def split_sequence(sequence, n_steps):
# 	X, y = list(), list()
# 	for i in range(len(sequence)):
# 		# find the end of this pattern
# 		end_ix = i + n_steps
# 		# check if we are beyond the sequence
# 		if end_ix > len(sequence)-1:
# 			break
# 		# gather input and output parts of the pattern
# 		seq_x, seq_y = sequence[i:end_ix], sequence[end_ix]
# 		X.append(seq_x)
# 		y.append(seq_y)
# 	return array(X), array(y)
 
# # define input sequence
# raw_seq = [10, 20, 30, 40, 50, 60, 70, 80, 90]
# # choose a number of time steps
# n_steps = 3
# # split into samples
# X, y = split_sequence(raw_seq, n_steps)
# # reshape from [samples, timesteps] into [samples, timesteps, features]
# n_features = 1
# X = X.reshape((X.shape[0], X.shape[1], n_features))
# # define model
# model = Sequential()
# model.add(LSTM(50, activation='relu', return_sequences=True, input_shape=(n_steps, n_features)))
# model.add(LSTM(50, activation='relu'))
# model.add(Dense(1))
# model.compile(optimizer='adam', loss='mse')
# # fit model
# model.fit(X, y, epochs=200, verbose=0)
# # demonstrate prediction
# x_input = array([70, 80, 90])
# x_input = x_input.reshape((1, n_steps, n_features))
# yhat = model.predict(x_input, verbose=0)
# print(yhat)
# Out:
# [[101.60282]]

# %%
# # univariate cnn lstm example
# from numpy import array
# from keras.models import Sequential
# from keras.layers import LSTM
# from keras.layers import Dense
# from keras.layers import Flatten
# from keras.layers import TimeDistributed
# from keras.layers.convolutional import Conv1D
# from keras.layers.convolutional import MaxPooling1D
 
# # split a univariate sequence into samples
# def split_sequence(sequence, n_steps):
# 	X, y = list(), list()
# 	for i in range(len(sequence)):
# 		# find the end of this pattern
# 		end_ix = i + n_steps
# 		# check if we are beyond the sequence
# 		if end_ix > len(sequence)-1:
# 			break
# 		# gather input and output parts of the pattern
# 		seq_x, seq_y = sequence[i:end_ix], sequence[end_ix]
# 		X.append(seq_x)
# 		y.append(seq_y)
# 	return array(X), array(y)
 
# # define input sequence
# raw_seq = [10, 20, 30, 40, 50, 60, 70, 80, 90]
# # choose a number of time steps
# n_steps = 4
# # split into samples
# X, y = split_sequence(raw_seq, n_steps)
# # reshape from [samples, timesteps] into [samples, subsequences, timesteps, features]
# n_features = 1
# n_seq = 2
# n_steps = 2
# X = X.reshape((X.shape[0], n_seq, n_steps, n_features))
# # define model
# model = Sequential()
# model.add(TimeDistributed(Conv1D(filters=64, kernel_size=1, activation='relu'), input_shape=(None, n_steps, n_features)))
# model.add(TimeDistributed(MaxPooling1D(pool_size=2)))
# model.add(TimeDistributed(Flatten()))
# model.add(LSTM(50, activation='relu'))
# model.add(Dense(1))
# model.compile(optimizer='adam', loss='mse')
# # fit model
# model.fit(X, y, epochs=500, verbose=0)
# # demonstrate prediction
# x_input = array([60, 70, 80, 90])
# x_input = x_input.reshape((1, n_seq, n_steps, n_features))
# yhat = model.predict(x_input, verbose=0)
# print(yhat)
# Out:
# [[100.80112]]

# %% [markdown]
# # Adjusted Tests

# %% [markdown]
# ## Bidirectional LSTM

# %%
# split an univariate sequence into samples
def split_sequence(sequence, n_steps):
	X, y = [], []
	for i in range(len(sequence)):
		# find the end of this pattern
		end_ix = i + n_steps
		# check if we are beyond the sequence
		if end_ix > len(sequence)-1:
			break
		# gather input and output parts of the pattern
		X.append(sequence[i:end_ix])
		y.append(sequence[end_ix])
	return array(X), array(y)

# %%
TRAIN_LIMIT = 200
n_steps = 20

# %%
# define input sequence
raw_seq = y[:TRAIN_LIMIT]
# split into samples
x_heads, y_tails = split_sequence(raw_seq, n_steps)
# reshape from [samples, timesteps] into [samples, timesteps, features]
n_features = 1
x_heads = x_heads.reshape(x_heads.shape[0], x_heads.shape[1], n_features)
# define model
model = Sequential()
model.add(Bidirectional(LSTM(50, activation='relu', input_shape=(n_steps, n_features))))
#model.add(LSTM(50, activation='relu'))
model.add(Dense(1))
model.compile(optimizer='adam', loss='mse')
# fit model
model.fit(x_heads, y_tails, epochs=10, verbose=True)
# demonstrate prediction
x_input = array(y[TRAIN_LIMIT:TRAIN_LIMIT+n_steps])
x_input = x_input.reshape((1, n_steps, n_features))
yhat = model.predict(x_input, verbose=True)
print(yhat, y[TRAIN_LIMIT+n_steps])
# Out:
# Epoch 1/10
# 6/6 [==============================] - 3s 17ms/step - loss: 3410.2854
# Epoch 2/10
# 6/6 [==============================] - 0s 16ms/step - loss: 401.5467
# Epoch 3/10
# 6/6 [==============================] - 0s 19ms/step - loss: 432.4130
# Epoch 4/10
# 6/6 [==============================] - 0s 18ms/step - loss: 1068.0773
# Epoch 5/10
# 6/6 [==============================] - 0s 16ms/step - loss: 467.3914
# Epoch 6/10
# 6/6 [==============================] - 0s 17ms/step - loss: 240.2280
# Epoch 7/10
# 6/6 [==============================] - 0s 18ms/step - loss: 190.7997
# Epoch 8/10
# 6/6 [==============================] - 0s 19ms/step - loss: 97.8981
# Epoch 9/10
# 6/6 [==============================] - 0s 19ms/step - loss: 257.0009
# Epoch 10/10
# ...
# 1/1 [==============================] - 0s 319ms/step
# [[269.71704]] 264.6002168887572

# %%
[[269.7249]] 264.6002168887572

# %%
1/0
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-62-9e1622b385b6> in <module>
# ----> 1 1/0
#
# ZeroDivisionError: division by zero

# %% [markdown]
# ## CNN LSTM

# %%
from numpy import array
import keras
from keras.models import Sequential
from keras.layers import LSTM
from keras.layers import Dense
from keras.layers import Flatten
from keras.layers import TimeDistributed
from keras.layers.convolutional import Conv1D
from keras.layers.convolutional import MaxPooling1D
from keras.callbacks import ModelCheckpoint

# %%
def split_sequence(sequence, n_sample_x):
	X, y = [], []
	for i in range(len(sequence)):
		# find the end of this pattern
		end_ix = i + n_sample_x
		# check if we are beyond the sequence
		if end_ix > len(sequence)-1:
			break
		# gather input and output parts of the pattern
		X.append(sequence[i:end_ix])
		y.append(sequence[end_ix])
	return array(X), array(y)

# %%
n_sample_x = 1000
n_features = 1
n_subsets = 2
TRAIN_LIMIT = 25000
n_sample_x_per_subset = int(n_sample_x/n_subsets)

# %%
train = y[:TRAIN_LIMIT]
test = y[TRAIN_LIMIT:]

# %%
cpt_path = '/content/drive/MyDrive/Colab Notebooks/keras_models/cnn_lstm/cnn_lstm.hdf5'
from google.colab import drive
drive.mount('/content/drive')
model = keras.models.load_model('/content/drive/MyDrive/Colab Notebooks/keras_models/cnn_lstm.h5')
checkpoint = ModelCheckpoint(cpt_path, monitor='val_loss', verbose=1, save_best_only=True, mode='min')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# split into samples
x_train, y_train = split_sequence(train, n_sample_x)
# reshape from [samples, timesteps] into [samples, subsequences, timesteps, features]
x_train = x_train.reshape((x_train.shape[0], n_subsets, n_sample_x_per_subset, n_features))

# %%
# # define model
# model = Sequential()
# model.add(TimeDistributed(MaxPooling1D(pool_size=2)))
# model.add(TimeDistributed(MaxPooling1D(pool_size=2)))
# model.add(TimeDistributed(MaxPooling1D(pool_size=2)))
# model.add(TimeDistributed(MaxPooling1D(pool_size=2)))
# model.add(TimeDistributed(MaxPooling1D(pool_size=2)))
# model.add(TimeDistributed(MaxPooling1D(pool_size=2)))
# model.add(TimeDistributed(MaxPooling1D(pool_size=2)))
# model.add(TimeDistributed(Conv1D(filters=64, kernel_size=1, activation='relu'),
#                           input_shape=(None, n_sample_x_per_subset, n_features)))

# model.add(TimeDistributed(Flatten()))
# model.add(LSTM(50, activation='relu'))
# model.add(Dense(1))
# model.compile(optimizer='adam', loss='mse')
# # fit model

# %%
# %%time
model.fit(x_train, y_train, epochs=10, verbose=True, batch_size=1000)
# Out:
# Epoch 1/10
# 24/24 [==============================] - 3s 128ms/step - loss: 183236640.0000
# Epoch 2/10
# 24/24 [==============================] - 2s 70ms/step - loss: 180621280.0000
# Epoch 3/10
# 24/24 [==============================] - 2s 70ms/step - loss: 181049200.0000
# Epoch 4/10
# 24/24 [==============================] - 2s 72ms/step - loss: 183923872.0000
# Epoch 5/10
# 24/24 [==============================] - 2s 71ms/step - loss: 181227584.0000
# Epoch 6/10
# 24/24 [==============================] - 2s 69ms/step - loss: 180310096.0000
# Epoch 7/10
# 24/24 [==============================] - 2s 71ms/step - loss: 179856064.0000
# Epoch 8/10
# 24/24 [==============================] - 2s 69ms/step - loss: 181755536.0000
# Epoch 9/10
# 24/24 [==============================] - 2s 69ms/step - loss: 184663696.0000
# Epoch 10/10
# 24/24 [==============================] - 2s 72ms/step - loss: 180626944.0000
# CPU times: user 27.7 s, sys: 924 ms, total: 28.6 s
# Wall time: 18.8 s

# %%
x_test, y_test = split_sequence(test, n_sample_x)
x_test = x_test.reshape((x_test.shape[0], n_subsets, n_sample_x_per_subset, n_features))
y_pred = model.predict(x_test, verbose=True).flatten()
#print(list(zip(y_test, y_pred)))
# Out:
# 9/9 [==============================] - 0s 5ms/step

# %%
plt.figure(figsize=(24,3))
plt.scatter(x_date, y)
plt.scatter(x_date[TRAIN_LIMIT + n_sample_x:], y_pred)
plt.show()

# %%
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_percentage_error

# %%
mean_squared_error(y_test, y_pred, squared=False)
# Out:
# 61358.28771613874

# %%
mean_absolute_percentage_error(y_test, y_pred)
# Out:
# 0.01016523428962067

# %%
model.save('/content/drive/MyDrive/Colab Notebooks/keras_models/cnn_lstm.h5')

# %% [markdown]
# # Test Forecaster

# %%
! pip install scalecast

# %%
from scalecast.Forecaster import Forecaster

# %%
f = Forecaster(y=y[:650], current_dates=x_date[:650])

# %%
f
# Out:
# Forecaster(
#     DateStartActuals=2022-01-01T00:00:00.000000000
#     DateEndActuals=2022-01-28T01:00:00.000000000
#     Freq=H
#     N_actuals=650
#     ForecastLength=0
#     Xvars=[]
#     Differenced=0
#     TestLength=1
#     ValidationLength=1
#     ValidationMetric=rmse
#     ForecastsEvaluated=[]
#     CILevel=0.95
#     BootstrapSamples=100
#     CurrentEstimator=None
#     GridsFile=Grids
# )

# %%
f.set_test_length(12)
f.generate_future_dates(35*24)
f.set_estimator('lstm')

# %%
f.set_test_length(30*24)
f.generate_future_dates((len(y)-650)*24)
f.set_estimator('lstm')

# %%
f.manual_forecast()
f.plot_test_set(ci=True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-64-5fe24bc0ec50> in <module>
# ----> 1 f.manual_forecast()
#       2 f.plot_test_set(ci=True)
#
# /usr/local/lib/python3.7/dist-packages/scalecast/Forecaster.py in manual_forecast(self, call_me, dynamic_testing, test_only, **kwargs)
#    4075             if self.estimator in _sklearn_estimators_
#    4076             else getattr(self, f"_forecast_{self.estimator}")(
# -> 4077                 dynamic_testing=dynamic_testing, test_only=test_only, **kwargs
#    4078             )
#    4079         )  # 0 - forecast, 1 - fitted vals, 2 - Xvars, 3 - regr
#
# /usr/local/lib/python3.7/dist-packages/scalecast/Forecaster.py in _forecast_lstm(self, dynamic_testing, lags, lstm_layer_sizes, dropout, loss, activation, optimizer, learning_rate, random_seed, plot_loss, test_only, **kwargs)
#    1323             **kwargs,
# ...
